# %%
# %pylab inline
import svgwrite
import eucare as ec
import eucare.redering as rend

# %%
#%matplotlib notebook
G = ec.example_graphs.from_tiles(ec.example_tilesets.pgg_2x(), rings=2)
renderer = ec.redering.SvgwriteRenderer()
renderer.render_graph('test.svg', G, height=10)

# %%
[i + j for i in range(2) for j in [10, 20]]
